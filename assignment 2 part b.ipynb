# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
data=np.random.rand(1252)
plt.hist(data)
plt.show()

# %%
# symmetric uniform distribution

# %%
import numpy as np
data=np.random.exponential(5,10000)
plt.hist(data)
plt.show()

# %%
#right hand skewed

# %%
import numpy as np
data=np.random.normal(1,1000000,1000000)
plt.hist(data)
plt.show()

# %%
# symmetric single peak distribution( bell type )
